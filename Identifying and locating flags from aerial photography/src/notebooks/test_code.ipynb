# %%
import os 
import shutil

file_needed_img_path = r"C:\Users\saher\Desktop\saher.txt"
all_img_path = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\data\inserted_flags_in_background\images"
distination = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\data\yes_no\images" 

li = []

# readlines it read line by line with \n (new line)
# readline itread only one line but read char by char and resulte in a list

with open(file_needed_img_path , 'r') as f :
    lines = f.readlines()
    for file in lines :
        li.append(file)

# %%
li
# Out:
# ['background_only_411.jpg\n',
#  'background_only_413.jpg\n',
#  'background_only_422.jpg\n',
#  'background_only_423.jpg\n',
#  'background_only_425.jpg\n',
#  'background_only_434.jpg\n',
#  'background_only_435.jpg\n',
#  'background_only_440.jpg\n',
#  'background_only_446.jpg\n',
#  'background_only_447.jpg\n',
#  'background_only_476.jpg\n',
#  'background_only_477.jpg\n',
#  'background_only_482.jpg\n',
#  'background_only_483.jpg\n',
#  'background_only_485.jpg\n',
#  'background_only_486.jpg\n',
#  'background_only_488.jpg\n',
#  'background_only_489.jpg\n',
#  'background_only_491.jpg\n',
#  'background_only_494.jpg\n',
#  'background_only_495.jpg\n',
#  'background_only_497.jpg\n',
#  'background_only_498.jpg\n',
#  'background_only_499.jpg\n',
#  'bahrain_0_160.jpg\n',
#  'bahrain_0_320.jpg\n',
#  'bahrain_0_400.jpg\n',
#  'bahrain_130_0.jpg\n',
#  'bahrain_130_320.jpg\n',
#  'bahrain_130_80.jpg\n',
#  'belgium_260_1040.jpg\n',
#  'belgium_260_1120.jpg\n',
#  'belgium_260_1200.jpg\n',
#  'belgium_390_880.jpg\n',
#  'belgium_390_960.jpg\n',
#  'brazil_520_1120.jpg\n',
#  'brazil_520_1200.jpg\n',
#  'brazil_520_160.jpg\n',
#  'brazil_520_240.jpg\n',
#  'brazil_650_0.jpg\n',
#  'china_130_720.jpg\n',
#  'china_520_1040.jpg\n',
#  'china_650_800.jpg\n',
#  'china_650_880.jpg\n',
#  'croatia_0_640.jpg\n',
#  'egypt_s2_260_880.jpg\n',
#  'egypt_s2_260_960.jpg\n',
#  'egypt_s2_390_640.jpg\n',
#  'egypt_s2_390_720.jpg\n',
#  'ethiopia_260_480.jpg\n',
#  'ethiopia_260_560.jpg\n',
#  'ethiopia_390_240.jpg\n',
#  'ethiopia_390_320.jpg\n',
#  'germany_0_320.jpg\n',
#  'germany_0_400.jpg\n',
#  'germany_130_0.jpg\n',
#  'germany_130_160.jpg\n',
#  'germany_130_80.jpg\n',
#  'greece_390_1200.jpg\n',
#  'greece_390_160.jpg\n',
#  'greece_390_240.jpg\n',
#  'greece_520_0.jpg\n',
#  'greece_520_1040.jpg\n',
#  'india_s2_0_800.jpg\n',
#  'india_s2_650_560.jpg\n',
#  'india_s2_650_640.jpg\n',
#  'india_s3_0_320.jpg\n',
#  'india_s3_0_400.jpg\n',
#  'iran_520_0.jpg\n',
#  'iran_520_1040.jpg\n',
#  'iran_520_1120.jpg\n',
#  'iran_520_80.jpg\n',
#  'italy_390_480.jpg\n',
#  'italy_390_560.jpg\n',
#  'italy_520_160.jpg\n',
#  'italy_520_240.jpg\n',
#  'japan_390_160.jpg\n',
#  'japan_390_240.jpg\n',
#  'japan_390_320.jpg\n',
#  'japan_390_400.jpg\n',
#  'japan_520_80.jpg\n',
#  'jordan_130_1200.jpg\n',
#  'jordan_130_160.jpg\n',
#  'jordan_260_0.jpg\n',
#  'jordan_390_640.jpg\n',
#  'jordan_390_720.jpg\n',
#  'jordan_390_800.jpg\n',
#  'jordan_520_400.jpg\n',
#  'korea_260_560.jpg\n',
#  'korea_260_640.jpg\n',
#  'korea_390_320.jpg\n',
#  'korea_390_400.jpg\n',
#  'kuwait_260_1200.jpg\n',
#  'kuwait_260_160.jpg\n',
#  'kuwait_260_240.jpg\n',
#  'kuwait_390_0.jpg\n',
#  'lebanon_130_1120.jpg\n',
#  'lebanon_130_1200.jpg\n',
#  'lebanon_130_160.jpg\n',
#  'lebanon_130_80.jpg\n',
#  'libya_650_800.jpg\n',
#  'libya_650_880.jpg\n',
#  'libya_s_0_560.jpg\n',
#  'libya_s_0_640.jpg\n',
#  'libya_s_0_720.jpg\n',
#  'mexico_0_1120.jpg\n',
#  'mexico_0_1200.jpg\n',
#  'mexico_0_160.jpg\n',
#  'mexico_130_880.jpg\n',
#  'morocco_s_0_320.jpg\n',
#  'morocco_s_0_400.jpg\n',
#  'morocco_s_0_640.jpg\n',
#  'morocco_s_130_0.jpg\n',
#  'morocco_s_130_1040.jpg\n',
#  'morocco_s_130_320.jpg\n',
#  'morocco_s_130_80.jpg\n',
#  'new zealand_390_240.jpg\n',
#  'new zealand_390_400.jpg\n',
#  'new zealand_390_480.jpg\n',
#  'new zealand_520_1040.jpg\n',
#  'new zealand_520_1120.jpg\n',
#  'new zealand_520_160.jpg\n',
#  'new zealand_520_80.jpg\n',
#  'nigeria_260_160.jpg\n',
#  'nigeria_260_320.jpg\n',
#  'nigeria_260_400.jpg\n',
#  'nigeria_390_0.jpg\n',
#  'nigeria_390_80.jpg\n',
#  'oman_260_720.jpg\n',
#  'oman_390_560.jpg\n',
#  'oman_390_640.jpg\n',
#  'oman_520_240.jpg\n',
#  'oman_650_0.jpg\n',
#  'pakistan_260_320.jpg\n',
#  'pakistan_260_480.jpg\n',
#  'pakistan_260_560.jpg\n',
#  'pakistan_390_160.jpg\n',
#  'pakistan_390_240.jpg\n',
#  'portugal_130_240.jpg\n',
#  'portugal_130_320.jpg\n',
#  'portugal_130_400.jpg\n',
#  'portugal_130_480.jpg\n',
#  'portugal_260_160.jpg\n',
#  'portugal_260_80.jpg\n',
#  'qatar_260_640.jpg\n',
#  'qatar_390_400.jpg\n',
#  'qatar_520_160.jpg\n',
#  'qatar_520_320.jpg\n',
#  'romania_0_1040.jpg\n',
#  'romania_0_720.jpg\n',
#  'romania_0_880.jpg\n',
#  'romania_0_960.jpg\n',
#  'russian_650_240.jpg\n',
#  'russian_650_320.jpg\n',
#  'russian_650_400.jpg\n',
#  'russian_650_480.jpg\n',
#  'russian_650_560.jpg\n',
#  'south africa_130_160.jpg\n',
#  'south africa_130_320.jpg\n',
#  'south africa_130_400.jpg\n',
#  'south africa_260_0.jpg\n',
#  'south africa_260_1040.jpg\n',
#  'south africa_260_1120.jpg\n',
#  'south africa_260_80.jpg\n',
#  'sudan_260_320.jpg\n',
#  'sudan_260_400.jpg\n',
#  'sudan_390_0.jpg\n',
#  'sudan_390_160.jpg\n',
#  'sudan_390_240.jpg\n',
#  'sudan_390_80.jpg\n',
#  'sweden_650_1200.jpg\n',
#  'switzerland_0_0.jpg\n',
#  'switzerland_0_1040.jpg\n',
#  'switzerland_0_80.jpg\n',
#  'switzerland_0_960.jpg\n',
#  'switzerland_130_720.jpg\n',
#  'tunisia_390_560.jpg\n',
#  'tunisia_520_240.jpg\n',
#  'tunisia_520_320.jpg\n',
#  'tunisia_520_400.jpg\n',
#  'ukraine_0_400.jpg\n',
#  'ukraine_0_480.jpg\n',
#  'ukraine_130_1040.jpg\n',
#  'ukraine_130_1120.jpg\n',
#  'ukraine_130_80.jpg\n',
#  'yemen_s_260_800.jpg\n',
#  'yemen_s_390_560.jpg\n',
#  'yemen_s_520_320.jpg\n',
#  'yemen_s_520_320.jpg\n',
#  'yemen_s_650_0.jpg\n',
#  'yemen_s_650_960 - Copy.jpg\n']

# %%
from ultralytics import YOLO
import os , cv2

def get_labels(data):
    names = [c['name'] for c in data]
    labels_dictionary = {c['name']: i for i, c in enumerate(data)}
    num_of_labels = len(data)
    return names, labels_dictionary, num_of_labels

data = [
    {"name": "albania"},
    {"name": "algeria"},
    {"name": "argentina"},
    {"name": "australia"},
    {"name": "austria"},
    {"name": "bahrain"},
    {"name": "belgium"},
    {"name": "brazil"},
    {"name": "bulgaria"},
    {"name": "canada"},
    {"name": "china"},
    {"name": "croatia"},
    {"name": "egypt"},
    {"name": "ethiopia"},
    {"name": "france"},
    {"name": "germany"},
    {"name": "greece"},
    {"name": "india"},
    {"name": "iran"},
    {"name": "iraq"},
    {"name": "italy"},
    {"name": "japan"},
    {"name": "jordan"},
    {"name": "korea"},
    {"name": "kuwait"},
    {"name": "lebanon"},
    {"name": "libya"},
    {"name": "mexico"},
    {"name": "morocco"},
    {"name": "new zealand"},
    {"name": "nigeria"},
    {"name": "oman"},
    {"name": "pakistan"},
    {"name": "portugal"},
    {"name": "qatar"},
    {"name": "romania"},
    {"name": "russian"},
    {"name": "saudi arabia"},
    {"name": "south africa"},
    {"name": "spain"},
    {"name": "sudan"},
    {"name": "sweden"},
    {"name": "switzerland"},
    {"name": "tunisia"},
    {"name": "turkey"},
    {"name": "ukraine"},
    {"name": "yemen"},
]

names, labels_dictionary, num_of_labels = get_labels(data)

# %%
labels_dictionary
# Out:
# {'albania': 0,
#  'algeria': 1,
#  'argentina': 2,
#  'australia': 3,
#  'austria': 4,
#  'bahrain': 5,
#  'belgium': 6,
#  'brazil': 7,
#  'bulgaria': 8,
#  'canada': 9,
#  'china': 10,
#  'croatia': 11,
#  'egypt': 12,
#  'ethiopia': 13,
#  'france': 14,
#  'germany': 15,
#  'greece': 16,
#  'india': 17,
#  'iran': 18,
#  'iraq': 19,
#  'italy': 20,
#  'japan': 21,
#  'jordan': 22,
#  'korea': 23,
#  'kuwait': 24,
#  'lebanon': 25,
#  'libya': 26,
#  'mexico': 27,
#  'morocco': 28,
#  'new zealand': 29,
#  'nigeria': 30,
#  'oman': 31,
#  'pakistan': 32,
#  'portugal': 33,
#  'qatar': 34,
#  'romania': 35,
#  'russian': 36,
#  'saudi arabia': 37,
#  'south africa': 38,
#  'spain': 39,
#  'sudan': 40,
#  'sweden': 41,
#  'switzerland': 42,
#  'tunisia': 43,
#  'turkey': 44,
#  'ukraine': 45,
#  'yemen': 46}

# %%
import os , shutil




flag_classification_path = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\data\flag_classification"


flags = os.listdir(flag_classification_path)

# for flag in flags:
#     # flag_folder = os.path.join(flag_classification_path , flag.strip('_'))
#     print(flag.strip('_'))

print(type(flags[0]))
print(flags[0])
print(flags[0].strip('g')) # remove from beggin and last only
print(flags[0].split('_'))
# Out:
# <class 'str'>
# algeria_0_0.jpg
# algeria_0_0.jp
# ['algeria', '0', '0.jpg']

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from geopy.distance import geodesic

# ========== إعداد المسارات ========== #
IMG_PATH = r"C:\Users\saher\Pictures\Screenshots\Screenshot 2025-07-09 163409.png"
MODEL_PATH = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\models\trained_models\flags_final_yolov8x_new_v1_flag_or_not_are_renamed\weights\best.pt"

# ========== مصفوفة الكاميرا ومعاملات ========== #
K = np.array([[2900, 0, 2048],
              [0, 2900, 1080],
              [0,    0,    1]], dtype=np.float32)
DIST_COEFFS = np.zeros((5,), dtype=np.float32)

# ========== بيانات الطائرة ========== #
DRONE_LAT, DRONE_LON = 30.1, 30.6
DRONE_ALT = 70.0  # بالأمتار

# ========== تحميل موديل YOLO ========== #
model = YOLO(MODEL_PATH)

# ========== دوال مساعده ========== #
def undistort_and_ray(cx: int, cy: int):
    """حول نقطة بكسل إلى شعاع في فضاء الكاميرا."""
    pts = np.array([[[cx, cy]]], dtype=np.float32)
    norm = cv2.undistortPoints(pts, K, DIST_COEFFS)
    x, y = norm[0, 0]
    return np.array([x, y, 1.0], dtype=np.float32)


def pixel_to_geo(cx: int, cy: int):
    """أحسب إحداثيات جغرافية (lat, lon) لنقطة مركز المربع."""
    ray = undistort_and_ray(cx, cy)
    scale = DRONE_ALT / ray[2]
    dx, dy = ray[0] * scale, ray[1] * scale
    mid = geodesic(meters=dy).destination((DRONE_LAT, DRONE_LON), 0)
    dest = geodesic(meters=dx).destination((mid.latitude, mid.longitude), 90)
    return dest.latitude, dest.longitude



frame = cv2.imread(IMG_PATH)
if frame is None:
    raise FileNotFoundError(f"Cannot read image: {IMG_PATH}")

# إعادة تحجيم للصورة إن كانت كبيرة
h, w = frame.shape[:2]
max_dim = max(h, w)
if max_dim > 1024:
    scale = 1024 / max_dim
    resized = cv2.resize(frame, (int(w * scale), int(h * scale)), interpolation=cv2.INTER_LINEAR)
else:
    resized = frame.copy()

# inference مع FP16 إذا كانت GPU تدعمه
results = model.predict(resized, conf=0.1, device=0, half=True)
# Out:
# 0: 576x1024 1 flag, 101.9ms
# Speed: 15.5ms preprocess, 101.9ms inference, 225.7ms postprocess per image at shape (1, 3, 576, 1024)

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'flag'}
# obb: None
# orig_img: array([[[ 92,  89,  76],
#         [ 89,  90,  77],
#         [ 88,  91,  77],
#         ...,
#         [101, 101,  90],
#         [101, 101,  90],
#         [100, 100,  89]],
#
#        [[ 93,  90,  77],
#         [ 91,  90,  77],
#         [ 92,  91,  78],
#         ...,
#         [101, 101,  90],
#         [101, 101,  90],
#         [100, 100,  89]],
#
#        [[ 93,  90,  76],
#         [ 92,  90,  77],
#         [ 93,  91,  78],
#         ...,
#         [101, 101,  90],
#         [101, 101,  90],
#         [100, 100,  89]],
#
#        ...,
#
#        [[ 93,  96,  84],
#         [ 88,  91,  79],
#         [ 92,  95,  83],
#         ...,
#         [127, 116,  94],
#         [125, 115,  91],
#         [125, 115,  91]],
#
#        [[ 92,  94,  83],
#         [ 92,  95,  83],
#         [ 90,  93,  81],
#         ...,
#         [127, 116,  94],
#         [125, 115,  91],
#         [125, 115,  91]],
#
#        [[ 92,  95,  83],
#         [ 86,  88,  77],
#         [ 89,  92,  80],
#         ...,
#         [125, 114,  93],
#         [125, 115,  91],
#         [125, 115,  91]]], dtype=uint8)
# orig_shape: (576, 1024)
# path: 'image0.jpg'
# probs: None
# save_dir: 'c:\\Users\\saher\\runs\\detect\\predict'
# speed: {'preprocess': 15.535799999980782, 'inference': 101.87460000000215, 'postprocess': 225.6594999999777}

# %%
for res in results:
    boxes = res.boxes.data.cpu().numpy()
    for x1, y1, x2, y2, conf, cls_id in boxes:
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
        label = model.names[int(cls_id)]
        cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
        lat, lon = pixel_to_geo(cx, cy)

        # رسم المستطيل والنص
        cv2.rectangle(resized, (x1, y1), (x2, y2), (0, 255, 0), 2)
        text = f"{label} ({conf:.2f})"
        cv2.putText(resized, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
        coord_text = f"{lat:.5f}, {lon:.5f}"
        cv2.putText(resized, coord_text, (x1, y2 + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)

        # قصّ العلم وتكبيره (عرض فقط، بدون حفظ)
        pad = 5
        crop = frame[max(0, y1 - pad):min(h, y2 + pad), max(0, x1 - pad):min(w, x2 + pad)]
        if crop.size > 0:
            up = cv2.resize(crop, (crop.shape[1] * 8, crop.shape[0] * 8), interpolation=cv2.INTER_LANCZOS4)
            cv2.imshow(f"Crop_{label}", up)

# عرض النتيجة النهائية
cv2.imshow("Detection", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
