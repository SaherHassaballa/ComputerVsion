# %%
from ultralytics import YOLO
import os

# %%
path_yolo_folder = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\models\yolo"

os.makedirs(path_yolo_folder , exist_ok = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 path_yolo_folder = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\models\yolo"
# ----> 3 os.makedirs(path_yolo_folder , exist_ok = True)
#
# NameError: name 'os' is not defined

# %%
import gc, torch
gc.collect()
torch.cuda.empty_cache()

# %%
# path_yolo = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\models\yolo\yolov8l.pt"

# model = YOLO(path_yolo)

# %%
from ultralytics import YOLO
import os

# %%
model_url = r"d:\github lite\cv_projects\Identifying and locating flags from aerial photography\models\trained_models\fuck any one8\weights\best.pt"
# model = YOLO("yolo11l.pt")
model = YOLO(model_url)

# %%
from ultralytics import YOLO

path_yaml = r"D:\github lite\cv_projects\Identifying and locating flags from aerial photography\data\inserted_flags_in_background\flage_on desert_not_roat\data.yaml"

model.train(
    data=path_yaml,      
    epochs=20,
    batch = 8,
    #cache = True           # يخزن الصور في الذاكرة لتسريع التدريب
    cache='disk',
    imgsz=512,            # حجم صورة أصغر لتسريع التدريب
    lr0=0.001,
    optimizer='SGD',
    
    augment=False,
    amp=True,            # تسريع باستخدام نصف الدقة (لو الكارت بيدعم)
    patience=5,
    device=0,            # استخدام كارت الشاشة
    project=r"C:\model",
    name="flags_countours_yolov11l_v1"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.161 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.158  Python-3.9.21 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolo11x.pt")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#       2 model = YOLO("yolo11x.pt")
#
# File c:\Users\saher\anaconda3\envs\tf-gpu-lite\lib\site-packages\ultralytics\__init__.py:11
#       8 if not os.environ.get("OMP_NUM_THREADS"):
#       9     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, YOLOE, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#      13 from ultralytics.utils.checks import check_yolo as checks
#
# File c:\Users\saher\anaconda3\envs\tf-gpu-lite\lib\site-packages\ultralytics\models\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .fastsam import FastSAM
#       4 from .nas import NAS
# ...
